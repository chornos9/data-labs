# %%
import pandas as pd
import numpy as np
import matplotlib 
# %matplotlib inline

# %%
data = pd.read_csv("./flights_tickets_serp2018-12-16.csv") 
data.head(2)
# Out:
#             searchTerms  rank  \
# 0  flights to hong kong     1
# 1  flights to hong kong     2
#
#                                                title  \
# 0  Cheap Flights to Hong Kong (HKG) from $397 - K...
# 1  $480 Flights to Hong Kong, China (HKG) - TripA...
#
#                                              snippet          displayLink  \
# 0  Find flights to Hong Kong on XiamenAir, Hong K...        www.kayak.com
# 1  Cheap Flights to Hong Kong: Enter your dates o...  www.tripadvisor.com
#
#                                                 link  \
# 0  https://www.kayak.com/flight-routes/United-Sta...
# 1  https://www.tripadvisor.com/Flights-g294217-Ho...
#
#                           queryTime  totalResults       cacheId  \
# 0  2018-12-16 11:26:30.485612+00:00     106000000  W42baDpas_gJ
# 1  2018-12-16 11:26:30.485612+00:00     106000000  5jsjhmxgxvkJ
#
#                                         formattedUrl  ... count startIndex  \
# ...

# %%
data.drop(['cacheId','link','htmlFormattedUrl','kind','count','startIndex','pagemap','formattedSearchTime','formattedTotalResults','gl','formattedUrl','inputEncoding','safe','cx','outputEncoding','htmlSnippet','htmlTitle', 'cseName'], axis=1, inplace=True)
data.head(2)
# Out:
#             searchTerms  rank  \
# 0  flights to hong kong     1
# 1  flights to hong kong     2
#
#                                                title  \
# 0  Cheap Flights to Hong Kong (HKG) from $397 - K...
# 1  $480 Flights to Hong Kong, China (HKG) - TripA...
#
#                                              snippet          displayLink  \
# 0  Find flights to Hong Kong on XiamenAir, Hong K...        www.kayak.com
# 1  Cheap Flights to Hong Kong: Enter your dates o...  www.tripadvisor.com
#
#                           queryTime  totalResults  searchTime
# 0  2018-12-16 11:26:30.485612+00:00     106000000    0.162895
# 1  2018-12-16 11:26:30.485612+00:00     106000000    0.162895

# %%
data.shape
# Out:
# (4000, 8)

# %%
data.head(3)
# Out:
#             searchTerms  rank  \
# 0  flights to hong kong     1
# 1  flights to hong kong     2
# 2  flights to hong kong     3
#
#                                                title  \
# 0  Cheap Flights to Hong Kong (HKG) from $397 - K...
# 1  $480 Flights to Hong Kong, China (HKG) - TripA...
# 2  Cheap Flights to Hong Kong International from ...
#
#                                              snippet          displayLink  \
# 0  Find flights to Hong Kong on XiamenAir, Hong K...        www.kayak.com
# 1  Cheap Flights to Hong Kong: Enter your dates o...  www.tripadvisor.com
# 2  Search cheap flights using Skyscanner's free f...   www.skyscanner.com
#
#                           queryTime  totalResults  searchTime
# 0  2018-12-16 11:26:30.485612+00:00     106000000    0.162895
# 1  2018-12-16 11:26:30.485612+00:00     106000000    0.162895
# 2  2018-12-16 11:26:30.485612+00:00     106000000    0.162895

# %%
#differents links (PAges) where people buy tickets

pages = data['displayLink'].unique()
len(pages)
# Out:
# 271

# %%
destinies = data['searchTerms'].unique()
len(destinies)
# Out:
# 200

# %%
pd.pivot_table(columns = 'displayLink', data = data)
# Out:
# displayLink   billetterie.ogcnice.com        bkk.hu  ca.jetcost.com  \
# rank                     6.000000e+00  5.000000e+00    6.750000e+00
# searchTime               3.072950e-01  2.418930e-01    3.134513e-01
# totalResults             3.990000e+08  3.720000e+07    1.379250e+08
#
# displayLink   discovercracow.com  dohahamadairport.com  edition.cnn.com  \
# rank                8.000000e+00          6.500000e+00     9.000000e+00
# searchTime          2.918380e-01          3.069625e-01     3.661660e-01
# totalResults        8.040000e+06          9.765000e+06     2.960000e+06
#
# displayLink   en.nice.aeroport.fr  en.tripadvisor.com.hk  en.wikipedia.org  \
# rank                 8.000000e+00               7.000000      7.666667e+00
# searchTime           2.474090e-01               0.517222      2.961380e-01
# totalResults         2.520000e+08          108000.000000      6.220500e+07
#
# displayLink   english.metro.taipei  ...  www.visit-angkor.org  \
# ...

# %%
destinies.split('tickets to')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-f92038bb7e91> in <module>
# ----> 1 destinies.split('tickets to')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'split'
